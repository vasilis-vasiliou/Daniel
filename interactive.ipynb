# %%
from tweets import scrape
tweets = scrape.get_tweets(search = "#storm #daniel until:2023-09-12 since:2023-09-01")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 from tweets import scrape
# ----> 2 tweets = scrape.get_tweets(search = "#storm #daniel until:2023-09-12 since:2023-09-01")
#
# TypeError: get_tweets() missing 1 required positional argument: 'max_tweets'

# %%
import pandas as pd

storm_daniel = pd.DataFrame(tweets)
display(storm_daniel)
# Out:
#                       id                                               text  \
# 0   -8238708678813758734  Storm #Daniel is causing severe flooding in ce...
# 1    4850915750951108897  Storm #Daniel is causing severe flooding in ce...
# 2   -4663322626663019157  Terrible floods due to heavy rains in the east...
# 3     178803502637576964  Terrible floods due to heavy rains in the east...
# 4    4613386882589871992  Terrible floods due to heavy rains in the east...
# 5    8232749148960759659  Terrible floods due to heavy rains in the east...
# 6    1928748464991040999  Terrible floods due to heavy rains in the east...
# 7   -4731186323164327508  Terrible floods due to heavy rains in the east...
# 8   -4093924983488349682  Terrible floods due to heavy rains in the east...
# 9    1556718742260762247  Terrible floods due to heavy rains in the east...
# 10  -5193295795096945109  #Libya'da Daniel fırtınası sonrası birçok şehi...
# ...

# %%
from tweets import scrape
tweets_thessaly = scrape.get_tweets(search = "#kategida #Thessaly #Daniel until:2023-09-12 since:2023-09-01")
# Out:
# Login successful!
# tweet by Marka2 @2023-09-07T21:22:49.000Z saying : 11χρονια περιφερειάρχης Θεσσαλίας
# Ξαναψηφιστε τον
# #Κακοκαιρία_Daniel #κακοκαιρια #καρδιτσα #Λάρισα
# tweet by Marka2 @2023-09-07T21:22:49.000Z saying : 11χρονια περιφερειάρχης Θεσσαλίας
# Ξαναψηφιστε τον
# #Κακοκαιρία_Daniel #κακοκαιρια #καρδιτσα #Λάρισα
# tweet by Marka2 @2023-09-07T21:22:49.000Z saying : 11χρονια περιφερειάρχης Θεσσαλίας
# Ξαναψηφιστε τον
# #Κακοκαιρία_Daniel #κακοκαιρια #καρδιτσα #Λάρισα
# tweet by Giorgos K. Koutras @2023-09-07T21:22:49.000Z saying : 11χρονια περιφερειάρχης Θεσσαλίας
# Ξαναψηφιστε τον
# #Κακοκαιρία_Daniel #κακοκαιρια #καρδιτσα #Λάρισα
# Skipping a tweet due to error: Message: stale element reference: stale element not found in the current frame
#   (Session info: chrome=132.0.6834.83); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#stale-element-reference-exception
# Stacktrace:
# ...

# %%
from tweets import scrape
tweets_thessaly = scrape.get_tweets(search = "#Θεσσαλία #κακοκαιρια #Daniel until:2023-09-12 since:2023-09-01")
# Out:
# Login successful!
# tweet by Counselor @2023-09-07T21:10:36.000Z saying : #Κίνδυνος #υπερχείλισης του #Πηνειού...
#
# #κακοκαιρια #Daniel #θεσσαλια #καρδιτσα #τρικαλα #λαρισα #μαγνησια
# tweet by Marka2 @2023-09-07T21:10:36.000Z saying : #Κίνδυνος #υπερχείλισης του #Πηνειού...
#
# #κακοκαιρια #Daniel #θεσσαλια #καρδιτσα #τρικαλα #λαρισα #μαγνησια
# tweet by Zoom Earth @2023-09-07T21:10:36.000Z saying : #Κίνδυνος #υπερχείλισης του #Πηνειού...
#
# #κακοκαιρια #Daniel #θεσσαλια #καρδιτσα #τρικαλα #λαρισα #μαγνησια
# tweet by Shadab Javed @2023-09-07T21:10:36.000Z saying : #Κίνδυνος #υπερχείλισης του #Πηνειού...
#
# #κακοκαιρια #Daniel #θεσσαλια #καρδιτσα #τρικαλα #λαρισα #μαγνησια
# Skipping a tweet due to error: Message: stale element reference: stale element not found in the current frame
#   (Session info: chrome=132.0.6834.83); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#stale-element-reference-exception
# ...

# %%
import pandas as pd 
tweets_thesallia_kakokeria = pd.DataFrame(tweets_thessaly)

# %%
display(tweets_thesallia_kakokeria)
# Out:
#                       id                                               text  \
# 0    4680046405438243623  #Κίνδυνος #υπερχείλισης του #Πηνειού...\n\n#κα...
# 1   -2662773304195766935  #Κίνδυνος #υπερχείλισης του #Πηνειού...\n\n#κα...
# 2   -8238708678813758734  #Κίνδυνος #υπερχείλισης του #Πηνειού...\n\n#κα...
# 3    6700167410194984447  #Κίνδυνος #υπερχείλισης του #Πηνειού...\n\n#κα...
# 4    4895709737050318008  Κάπου υπάρχει και δρόμος...\n#Καρδιτσα #Βολος ...
# 5    1359857452926119107  Κάπου υπάρχει και δρόμος...\n#Καρδιτσα #Βολος ...
# 6    9103992422579378773  Κάπου υπάρχει και δρόμος...\n#Καρδιτσα #Βολος ...
# 7    1804172847231628635  Κάπου υπάρχει και δρόμος...\n#Καρδιτσα #Βολος ...
# 8   -8613548181858230338  Κάπου υπάρχει και δρόμος...\n#Καρδιτσα #Βολος ...
# 9    5418977777617790606  Κάπου υπάρχει και δρόμος...\n#Καρδιτσα #Βολος ...
# 10   8807508044117827047  Κάπου υπάρχει και δρόμος...\n#Καρδιτσα #Βολος ...
# ...

# %%
data
# Out:
#     Unnamed: 0                   id  \
# 0            0  1832046299662860665
# 1            1  -706049450358421413
# 2            2 -4214728483515953129
# 3            3   -53741639400840232
# 4            4  3373479435806183222
# ..         ...                  ...
# 71          71  1875639887393831219
# 72          72  2294428360148070296
# 73          73  5250474852978228883
# 74          74  -854466804050503977
# 75          75  3329808243795817873
#
#                                                  text         user_name  \
# 0   #Borrasca #Daniel #borrascaDaniel\nFuertes #ll...   formación+salud
# 1   #Borrasca #Daniel #borrascaDaniel\nFuertes #ll...        Zoom Earth
# 2   #Borrasca #Daniel #borrascaDaniel\nFuertes #ll...          PxPx2025
# 3   #Borrasca #Daniel #borrascaDaniel\nFuertes #ll...        Zoom Earth
# 4   This was in central #Athens today\n#storm #Dan...  𝙺𝚘𝚜𝚝𝚊𝚜 𝙺𝚊𝚕𝚕𝚎𝚛𝚐𝚒𝚜
# ..                                                ...               ...
# ...

# %%
from IPython.display import display
pd.set_option('display.max_rows', None)
# Display the dataframe
display(data)
# Out:
#     Unnamed: 0                   id  \
# 0            0  1832046299662860665
# 1            1  -706049450358421413
# 2            2 -4214728483515953129
# 3            3   -53741639400840232
# 4            4  3373479435806183222
# 5            5 -6092895821802854891
# 6            6  6009916760831887805
# 7            7 -1974843862017232477
# 8            8 -1902213812594183098
# 9            9   165988289131764428
# 10          10 -7593120535439806434
# 11          11 -7267559020752946727
# 12          12 -3834347884719717301
# 13          13 -6819111097937342741
# 14          14   996473992927685026
# 15          15 -3047116353280651302
# 16          16  -353985391188980571
# 17          17 -2356011440163195231
# 18          18 -4045822123412936509
# 19          19   801250990125374793
# 20          20  -324119668455077871
# 21          21 -2586506396383634065
# 22          22 -8080095675961624460
# 23          23 -7602515966213385494
# 24          24  3401918853157143178
# ...

# %%
data2 = pd.read_csv('data/tweets2025-01-18 11:29:13.325289.csv')

# %%
from IPython.display import display
pd.set_option('display.max_rows', None)
# Display the dataframe
display(data2)
# Out:
#                      id                                               text  \
# 0  -6835181308392822815  #Borrasca #Daniel #borrascaDaniel\nFuertes #ll...
# 1  -8238708678813758734  #Borrasca #Daniel #borrascaDaniel\nFuertes #ll...
# 2  -6918559555776527349  This was in central #Athens today\n#storm #Dan...
# 3   8232749148960759659  This was in central #Athens today\n#storm #Dan...
# 4  -4663322626663019157  This was in central #Athens today\n#storm #Dan...
# 5    178803502637576964  This was in central #Athens today\n#storm #Dan...
# 6   8239857907814917174  This was in central #Athens today\n#storm #Dan...
# 7  -4093924983488349682  This was in central #Athens today\n#storm #Dan...
# 8   4613386882589871992  This was in central #Athens today\n#storm #Dan...
# 9   1055272741987985923  This was in central #Athens today\n#storm #Dan...
# 10 -1517512191818636526  مشاهد متداولة تظهر وصول العاصفة "دانيال" الى م...
# ...

# %%
tweets
# Out:
# [{'id': '-6835181308392822815',
#   'text': '#Borrasca #Daniel #borrascaDaniel\nFuertes #lluvias  #inundaciones en #Sciathos (#Skiathos), #Thessaly, #Grecia (#Greece).\n\n#floods #storm #rain\n#flooding #πλημμύρες',
#   'user_name': 'formación+salud',
#   'timestamp': '2023-09-06T09:31:04.000Z'},
#  {'id': '-8238708678813758734',
#   'text': '#Borrasca #Daniel #borrascaDaniel\nFuertes #lluvias  #inundaciones en #Sciathos (#Skiathos), #Thessaly, #Grecia (#Greece).\n\n#floods #storm #rain\n#flooding #πλημμύρες',
#   'user_name': 'Zoom Earth',
#   'timestamp': '2023-09-06T09:31:04.000Z'},
#  {'id': '4850915750951108897',
#   'text': '#Borrasca #Daniel #borrascaDaniel\nFuertes #lluvias  #inundaciones en #Sciathos (#Skiathos), #Thessaly, #Grecia (#Greece).\n\n#floods #storm #rain\n#flooding #πλημμύρες',
#   'user_name': 'PxPx2025',
#   'timestamp': '2023-09-06T09:31:04.000Z'},
#  {'id': '2596523027745887524',
# ...

# %%
import pandas as pd 

plimires = pd.read_csv('data/tweets2025-01-18 18:43:21.991478_#πλημμύρες #κακοκαιρια #Daniel until:2023-09-12 since:2023-09-01.csv')
derna = pd.read_csv('data/tweets2025-01-18 18:44:20.314751_#storm #daniel #derna until:2023-09-12 since:2023-09-01.csv')
thesally = pd.read_csv('data/tweets2025-01-18 18:45:53.168584_#storm #thessaly #daniel until:2023-09-12 since:2023-09-01.csv')

# %%
from IPython.display import display
pd.set_option('display.max_rows', None)
# Display the dataframe
display(plimires)
# Out:
#                       id                                               text  \
# 0   -3287622673129158305  Storm #Daniel is causing severe flooding in ce...
# 1   -6533227223864683870  Storm #Daniel is causing severe flooding in ce...
# 2    7789702019581372882  Storm #Daniel is causing severe flooding in ce...
# 3   -5553841022488792522  Storm #Daniel is causing severe flooding in ce...
# 4    1783902142247654913  Είναι δυνατο το κρατος να μην περισυλλέγει τα ...
# 5   -5425484307093926057  Είναι δυνατο το κρατος να μην περισυλλέγει τα ...
# 6    2518680172716112572  Είναι δυνατο το κρατος να μην περισυλλέγει τα ...
# 7    1392628028328429363  Είναι δυνατο το κρατος να μην περισυλλέγει τα ...
# 8    4278694435430198158  Είναι δυνατο το κρατος να μην περισυλλέγει τα ...
# 9   -2257955170693699006  Είναι δυνατο το κρατος να μην περισυλλέγει τα ...
# 10   -662483802990246396  Είναι δυνατο το κρατος να μην περισυλλέγει τα ...
# ...
